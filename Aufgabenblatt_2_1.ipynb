# %% [markdown]
# # Aufgabe 1 — Erste Schritte mit NumPy und matplotlib

# %%
import matplotlib.pyplot as plt
from skimage.io import imread
import numpy as np
img = imread('./catG.png')
plt.imshow(img , cmap='Greys_r', vmin=0, vmax=255)

# %%
#shape[0] = Zeilen
#shape[1] = Spalten
def countPixels():
  pixelCount = 0
  for x in range(img.shape[0]):
    for y in range(img.shape[1]):
      pixelCount += 1
  return pixelCount

countPixels()
# Out:
# 367500

# %%
def maxPixelValue():
  maximumValue = 0
  for x in range(img.shape[0]):
    for y in range(img.shape[1]):
      if(img[x,y] > maximumValue):
        maximumValue = img[x,y]
  return maximumValue

maxPixelValue()
# Out:
# 255

# %%
def minPixelValue():
  minimumValue = 255
  for x in range(img.shape[0]):
    for y in range(img.shape[1]):
      if(img[x,y] < minimumValue):
        minimumValue = img[x,y]
  return minimumValue

minPixelValue()
# Out:
# 0

# %%
def meanPixelValue():
  pixelCount = 0
  pixelSum = 0
  for x in range(img.shape[0]):
    for y in range(img.shape[1]):
      pixelCount += 1
      pixelSum += img[x,y]

  pixelMean = pixelSum/pixelCount
  return pixelMean

meanPixelValue()
# Out:
# 128.04654149659865

# %% [markdown]
# # Aufgabe 2 — Komplexere Bildstatistiken

# %%
def countWhitePixels():
  whitePixelSum = 0
  for x in range(img.shape[0]):
    for y in range(img.shape[1]):
      if img[x,y] == 255:
        whitePixelSum += 1

  return whitePixelSum

countWhitePixels()
# Out:
# 283

# %%
def countBlackPixels():
  blackPixelSum = 0
  for x in range(img.shape[0]):
    for y in range(img.shape[1]):
      if img[x,y] == 0:
        blackPixelSum += 1

  return blackPixelSum

countBlackPixels()
# Out:
# 13

# %%
def countGreyPixels():
  greyPixelList = []
  for x in range(img.shape[0]):
    for y in range(img.shape[1]):
      uniqueGreyPixel = img[x,y]
      greyPixelList.append(uniqueGreyPixel)

  for i in range(0,256):
    print(str(i)+": "+str(greyPixelList.count(i)))


countGreyPixels()
# Out:
# 0: 13
# 1: 3
# 2: 3
# 3: 3
# 4: 4
# 5: 2
# 6: 5
# 7: 0
# 8: 5
# 9: 5
# 10: 1
# 11: 3
# 12: 3
# 13: 5
# 14: 3
# 15: 5
# 16: 9
# 17: 11
# 18: 17
# 19: 11
# 20: 15
# 21: 19
# 22: 32
# 23: 40
# 24: 30
# 25: 46
# 26: 88
# 27: 93
# 28: 98
# 29: 104
# 30: 146
# 31: 195
# 32: 245
# 33: 268
# 34: 494
# 35: 611
# 36: 879
# 37: 907
# 38: 1107
# 39: 1401
# 40: 1250
# 41: 1520
# 42: 1518
# 43: 1832
# 44: 1585
# 45: 1307
# 46: 1029
# 47: 853
# 48: 785
# 49: 832
# 50: 900
# 51: 970
# 52: 1165
# 53: 1248
# 54: 1228
# 55: 1348
# 56: 1280
# 57: 1373
# 58: 1332
# 59: 1498
# 60: 1509
# 61: 1506
# 62: 1433
# 63: 1398
# 64: 1349
# 65: 1293
# 66: 1319
# 67: 1351
# 68: 1434
# 69: 1494
# 70: 1447
# 71: 1475
# 72: 1409
# 73: 1486
# 74: 1472
# 75: 1583
# 76: 1525
# 77: 1574
# 78: 1595
# 79: 1679
# 80: 1623
# 81: 1745
# 82: 1727
# 83: 1764
# 84: 1783
# 85: 1926
# 86: 1981
# 87: 1973
# 88: 2013
# 89: 2095
# 90: 2142
# 91: 2212
# 92: 2221
# 93: 2394
# 94: 2299
# 95: 2435
# 96: 2479
# 97: 2606
# 98: 2647
# ...

# %% [markdown]
# # Aufgabe 3 — NumPy Funktionen

# %%
print(np.max(img))
print(np.min(img))
print(np.mean(img))
# Out:
# 255
# 0
# 128.04654149659865

# %% [markdown]
# # Aufgabe 4 — Zusatzaufgabe: Einfache Bildtransformationen

# %%
def invertImg():
  for x in range(img.shape[0]):
    for y in range(img.shape[1]):
      img[x,y] = 255-img[x,y]

  plt.imshow(img , cmap='Greys_r', vmin=0, vmax=255)

invertImg()
